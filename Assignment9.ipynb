# %%
import pandas as pd
import numpy as np

# %%
#Read the dataset from the below link
#https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv

url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv"
df1 = pd.read_csv(url)
df1.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
#2.Show the distribution of male and female
df2=df1["Gender"].value_counts(dropna=True)
df2.head()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
#2.Show the distribution of male and female
df2=df1["Gender"].value_counts(dropna=False)
df2.head()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
#3. Show the top 5 most preferred names
#Sort the names by count in descendign and print the top any count

df1.sort_values("Name",ascending=False,inplace=True)

top5 = df1["Name"].value_counts(dropna=False)
top5.head(5)
# Out:
# Riley     1112
# Avery     1080
# Jordan    1073
# Peyton    1064
# Hayden    1049
# Name: Name, dtype: int64

# %%
#4. What is the median name occurence in the dataset
#med_name = df1.groupby('Name').median()
#med_name.head()
df1.reset_index().groupby('Name').median()
# Out:
#                index  Unnamed: 0         Id    Year  Count
# Name
# Aaban       694733.5   3866900.5  3866901.5  2013.5    6.0
# Aadan       131262.0    702439.0   702440.0  2008.5    5.5
# Aadarsh     323950.0   1728030.0  1728031.0  2009.0    5.0
# Aaden       516998.5   2867679.5  2867680.5  2010.0   10.0
# Aadhav      138429.0    709606.0   709607.0  2014.0    6.0
# Aadhya      512629.5   2837496.5  2837497.5  2013.0    8.0
# Aadi        515408.5   2888316.5  2888317.5  2009.0    7.0
# Aadin       897675.0   5061279.0  5061280.0  2008.0    5.0
# Aadit       121237.0    692414.0   692415.0  2008.0    6.0
# Aaditya     136986.0    708163.0   708164.0  2008.0    6.0
# Aadya       558596.5   3111600.5  3111601.5  2013.0    7.0
# Aadyn       350254.0   1860098.0  1860099.0  2009.0    6.0
# Aahan       120724.5    691901.5   691902.5  2008.0    7.0
# Aahana      105456.0    563519.0   563520.0  2011.0    7.0
# Aahil       694240.5   3866407.5  3866408.5  2012.0    7.0
# ...

# %%
#5. Distribution of male and female born count by states
df1.groupby(['State','Gender',])['Gender'].count().unstack()
# Out:
# Gender      F      M
# State
# AK       2404   2587
# AL       9878   8419
# AR       7171   6475
# AZ      14518  10820
# CA      45144  31637
# CO      11424   9183
# CT       6575   5733
# DC       3053   3000
# DE       2549   2440
# FL      25781  20070
# GA      19385  15454
# HI       3255   3546
# IA       7131   6307
# ID       4918   4833
# IL      21268  16828
# IN      13056  10613
# KS       7753   6748
# KY       8817   7267
# LA      10510   9676
# MA      10580   8609
# MD      11276   9483
# ME       2976   2777
# MI      16038  13243
# MN      10677   9004
# MO      11948   9917
# MS       7235   6862
# MT       2690   2986
# NC      17357  13530
# ND       2399   2581
# NE       5370   5029
# NH       2957   2659
# NJ      15041  12274
# NM       5721   4966
# NV       7092   6024
# NY      28158  22585
# OH      18143  14318
# OK       9519   8138
# OR       8604   7333
# PA      17480  14171
# RI       2558   2468
# SC       9465   8195
# SD       2838   2908
# ...
